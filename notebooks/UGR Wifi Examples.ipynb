# %% [markdown]
# # Wifi Sensor Networks for IoT
#
# Program all the Pis
#
# Sniff all the wifis
#
# Ingest all the data
#
# Hack all the things
#
# <img src="https://charlesreid1.com/w/images/0/02/HackDawg.jpg" width="300px" />

# %% [markdown]
# # Useful Links
#
# [MongoDB Documentation - Python](https://docs.mongodb.com/getting-started/python/query/)
#
# [PyMongo Documentation](https://api.mongodb.com/python/current/)
#
# [PyMongo Query Examples](https://api.mongodb.com/python/current/examples/index.html)

# %% [markdown]
# # Research Questions
#
# Here are a few research questions we may be interested in answering:
# * How many unique devices did we see in each experiment? (How busy is this area?)
# * How many unique access points did we see in each experiment? (How crowded are the airwaves?)
# * What channels are the most crowded?
# * What is the average duration for seeing a device?
# * What is the distribution of signal strengths?
# * What is the distribution of types of devices?
# * How much data are clients using, and what is the distribution of traffic?

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime
from pymongo import MongoClient

import re
import random
from pprint import pprint # Use pprint for printing out lists, one element per line

# %%
client = MongoClient('inspiring_boyd', 27017) # inspiring_boyd is the name of the MongoDB instance
db = client.wifi
client_collection = db.client_data
ap_collection = db.ap_data

# %% [markdown]
# # Simple Queries
#
# Start with a simple query to match *every* MAC address that we've seen:

# %%
cursor = client_collection.find()
for j,doc in enumerate(cursor):
    print "Client MAC Address: %s"%(doc['mac'])
    if(j>10):
        break
# Out:
# Client MAC Address: 30:CD:A7:30:4E:B5
# Client MAC Address: A8:BB:CF:20:81:70
# Client MAC Address: D8:5B:2A:DC:84:ED
# Client MAC Address: 1A:09:C2:1D:6F:D6
# Client MAC Address: 6E:BC:2D:E4:57:B1
# Client MAC Address: 84:7A:88:64:A3:FA
# Client MAC Address: 30:CD:A7:30:4E:B5
# Client MAC Address: 50:9E:A7:D9:ED:4B
# Client MAC Address: 30:8C:FB:89:C6:43
# Client MAC Address: 60:67:20:4D:1F:64
# Client MAC Address: C0:EE:FB:DE:66:68
# Client MAC Address: 30:CD:A7:30:4E:B5

# %% [markdown]
# Here is a query to match particular MAC addresses using a regular expression:

# %%
cursor = client_collection.find({'mac':{'$regex':'^AA'}}) # ^ means "start", so ^AA means "starts with AA"
for j,doc in enumerate( cursor ):
    print "Client MAC Address Starting With AA: %s"%(doc['mac'])
    if(j>10):
        break
# Out:
# Client MAC Address Starting With AA: AA:45:17:B6:11:C3
# Client MAC Address Starting With AA: AA:23:33:FF:7B:F9
# Client MAC Address Starting With AA: AA:F3:4E:64:FF:84
# Client MAC Address Starting With AA: AA:9B:16:F6:DB:34
# Client MAC Address Starting With AA: AA:9A:34:08:BD:1B
# Client MAC Address Starting With AA: AA:F3:4E:64:FF:84
# Client MAC Address Starting With AA: AA:C3:C3:D3:04:DA
# Client MAC Address Starting With AA: AA:A9:72:49:6C:75
# Client MAC Address Starting With AA: AA:2D:BE:83:28:94
# Client MAC Address Starting With AA: AA:7F:C7:E1:CF:A2
# Client MAC Address Starting With AA: AA:46:BF:D3:37:F9
# Client MAC Address Starting With AA: AA:C3:C3:D3:04:DA

# %% [markdown]
# # Unique Devices
#
# Unique devices can be identified using their MAC address, which is their digital fingerprint.
#
# To count all of the unique devices we saw in a given experiment, we can run a query to extract all MAC addresses for a given experiment, and add each MAC address to a set to create a unique list.

# %%
# This query extracts all MAC addresses 
# Needs to be adjusted to extract MAC addresses for one experiment
cursor = client_collection.find()

# Here's a short example:
s = set()
for j,doc in enumerate(cursor):
    s.add(doc['mac'])
    # Only print the first 10
    if(j>10):
        break

pprint(s)
# Out:
# set([u'1A:09:C2:1D:6F:D6',
#      u'30:8C:FB:89:C6:43',
#      u'30:CD:A7:30:4E:B5',
#      u'50:9E:A7:D9:ED:4B',
#      u'60:67:20:4D:1F:64',
#      u'6E:BC:2D:E4:57:B1',
#      u'84:7A:88:64:A3:FA',
#      u'A8:BB:CF:20:81:70',
#      u'C0:EE:FB:DE:66:68',
#      u'D8:5B:2A:DC:84:ED'])

# %%
# Here's a longer example:
cursor = client_collection.find()

s = set()
for j,doc in enumerate(cursor):
    s.add(doc['mac'])

print len(s)
# Out:
# 2035

# %% [markdown]
# # Unique Access Points
#
# Unique access points can also be identified using their MAC addresses, so counting up the number of unique access points looks pretty much the same.

# %%
# This query extracts all MAC addresses 
# Needs to be adjusted to extract MAC addresses for one experiment
cursor = ap_collection.find()

s = set()
for j,doc in enumerate(cursor):
    s.add(doc['bssid'])

print len(s)
# Out:
# 4261

# %% [markdown]
# # Channel Usage
#
# To check how crowded channels are, we can extract a list of channels used by access points; this will be a list like `[6, 6, 11, 6, 1, 7, 4, 6, 8, 6]`. If we plot a histogram of this list, that will show us which channels are the most crowded.

# %%
cursor = ap_collection.find()

channels = [] # for non-unique items, use a list, not a set!

for j,doc in enumerate(cursor):
    channels.append(doc['channel'])

# %% [markdown]
# Seaborn (sns) is a module for making nice, pretty plots. By default, the plots don't look that great:

# %%
# This makes a distribution plot
sns.distplot(channels)
plt.show()

# %% [markdown]
# But with a little bit of magic, they start to look a lot better:

# %%
ax = sns.distplot(channels,
                  kde=False,
                  hist_kws={'alpha':0.8},
                  color=sns.xkcd_rgb['brick red'])

ax.set_xlim([0,13])
ax.set_xlabel('Channel')
ax.set_ylabel('Number of Observations')
plt.show()

# %% [markdown]
# # Average Duration of Seeing a Device
#
# If we want to compute the average duration of seeing a wireless device (clients only, not access points), we should start with a list of unique clients. For each client, compute the duration by getting all timestamps associated with that device, and subtract the first timestamp from the last timestamp. Add each duration to a list, and then compute the average.

# %%
# Here is an example duration calculation for one client
# (we'll call our client Bilbo Baggins)

bilbo_baggins = '60:67:20:4D:1F:64'

cursor = client_collection.find({'mac': bilbo_baggins})

bilbo_timestamps = []
for j,doc in enumerate(cursor):
    bilbo_timestamps.append( doc['time'] )

print "Found %d matching timestamps"%(len(bilbo_timestamps))
# Out:
# Found 18 matching timestamps

# %% [markdown]
# As it turns out, MongoDB returns the data in correct datetime format, which means we can do algebra with the timestamps:

# %%
print type(bilbo_timestamps[0])

bilbo_timestamps.sort()
print "First seen: \t%s"%(bilbo_timestamps[0])
print "Last seen: \t%s"%(bilbo_timestamps[-1])
print "Duration: \t%s"%(bilbo_timestamps[-1] - bilbo_timestamps[0])
# Out:
# <type 'datetime.datetime'>
# First seen: 	2017-04-13 16:00:26
# Last seen: 	2017-04-13 17:58:27
# Duration: 	1:58:01

# %% [markdown]
# # Distribution of Signal Strengths
#
# We may want to examine the distribution of wireless signal strengths.

# %%
# This query extracts all MAC addresses 
# Needs to be adjusted to extract MAC addresses for one experiment
cursor = client_collection.find()

pwr = []
for j,doc in enumerate(cursor):
    pwr.append(doc['power'])

# %% [markdown]
# Once again, the data we extract from MongoDB has the correct type! (integer)

# %%
print type(pwr[0])

print len(pwr)
# Out:
# <type 'int'>
# 6003

# %%
#client_cursor = client_collection.find({'host': host, 
#                                        'time': {"$gt":datetime.datetime(2017,4,24), 
#                                                 "$lt": datetime.datetime(2017,4,25)} })

plt.rc('axes',titlesize = 25)
plt.rc('xtick',labelsize = 15)
plt.rc('ytick',labelsize = 15)

sns.set_style("whitegrid")

fig = plt.figure(figsize=(16,7))
ax = fig.add_subplot(111)
ax = sns.distplot(pwr,
                  kde=False,
                  bins=20,
                  hist_kws={'alpha':1},
                  color=sns.xkcd_rgb['shamrock green'])

ax.set_title('Signal Strength Distribution')
ax.set_xlabel('Signal Strength (dB)', fontsize = 15)
ax.set_ylabel('Number of Observations', fontsize = 15)
plt.show()

# %%
data = np.log((np.multiply(pwr,-1.0)))

# %%
plt.rc('axes',titlesize = 25)
plt.rc('xtick',labelsize = 15)
plt.rc('ytick',labelsize = 15)

sns.set_style("whitegrid")

fig = plt.figure(figsize=(16,7))
ax = fig.add_subplot(111)
ax = sns.distplot(data,
                  kde=False,
                  bins=75,
                  hist_kws={'alpha':1},
                  color=sns.xkcd_rgb['denim blue'])

ax.set_title('Log(Signal Strength)')
ax.set_xlabel('Signal Strength (dB)', fontsize = 15)
ax.set_ylabel('Number of Observations', fontsize = 15)

ax.set_xlim([3.0, 5.0])
plt.show()

# %% [markdown]
# If you take the log of the signal strength distribution,
#
# $$
# SS \sim \frac{1}{r^2}
# $$
#
# $$
# \log(SS) \sim -2 \log(r)
# $$
# So if slope of -2, then power of $1/r^2$.

# %% [markdown]
# # Grouping Experiments
#
# To group experiment data together, we can find records with `host` equal to `thing1` or `thing2`. We can narrow things down further by using date and time criteria.

# %%
# This query extracts all wifi network names seen by thing1.
cursor = ap_collection.find({'host': 'thing1'})

essids = set()
for j,doc in enumerate(cursor):
    essids.add(doc['essid'])

print("Saw %d networks:"%(len(essids)))
pprint(essids)
# Out:
# Saw 1839 networks:
# set([u'',
#      u'"305 for phone. "',
#      u'"City Paws Guest "',
#      u'"Dial-up "',
#      u'"Marlpy "',
#      u'"Spec Ops O "',
#      u'"WhateversClever "',
#      u'#spacecastlez',
#      u'(C(Jf6HAI3fKv)Hc',
#      u'-HOME-',
#      u'-_-',
#      u"....\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\xDD.\\x00....\\x00\\x00\\xFF.\\xDD.\\x00....\\x00.\\x00@\\x00\\xDD'\\x00P\\xF2..J\\x00...D\\x00",
#      u'001',
#      u'0024b100000220d2',
#      u'0A344ABB',
#      u'0A9988AN',
#      u'1-900-Mix-A-Lot',
#      u'10000ft',
#      u'1111 Engineering',
#      u'1111net_1',
#      u'1111net_2',
#      u'1111net_3',
#      u'1111net_4',
#      u'1111net_5',
#      u'1111net_6',
#      u'1111net_7',
#      u'1111net_8',
#      u'1111net_9',
#      u'11thAveInn',
#      u'1221 1st Ave 307',
#      u'12th Ave Rental',
#      u'1373Arlington',
#      u'1373Arlington-guest',
#      u'1415',
#      u'158 18th Ave Hello Neighbor!',
#      u'1915',
#      u'1EnergyCorp',
#      u'1EnergyGuest',
#      u'1st&Jackson',
#      u'20150604',
#      u'223vrbo',
#      u'22plsh',
#      u'2319MW',
#      u'2Dornot2D',
#      u'2turtledubs',
#      u'306',
#      u'315_6',
#      u'358_GUEST',
#      u'3Bros',
#      u'3PT-2.4',
#      u'40-aa',
#      u'4009 Network',
#      u'441',
#      u'445',
#      u'446',
#      u'480',
#      u'5003',
#      u'5003-guest',
#      u'603',
#      u'701C2.4',
#      u'713W',
#      u'748e',
#      u'805LWD',
#      u'80main702',
#      u'847',
#      u'8MKODPLI',
#      u'?',
#      u'AA3274',
#      u'ABHWiFi',
#      u'ABMSurfaceLot',
#      u'AG007',
#      u'AGUIRRE',
#      u'ALCHEMIE',
#      u'AMR',
#      u'AMREPCR',
#      u'ANICA_GUEST',
#      u'APHU1',
#      u'AProMutant',
#      u'AQ',
#      u'AR1',
#      u'ART_Guest',
#      u'ASI1511',
#      u'ASIwifi1001',
#      u'ASUS',
#      u'ASUSIM',
#      u'ASUS_2.4_Mo',
#      u'ASUSofSpades2',
#      u'ATG-CORP',
#      u'ATG-GUEST',
#      u'ATT-WIFI-0257',
#      u'ATT-WIFI-9710',
#      u'AV-LIB',
#      u'AaronShawnNetwork2',
#      u'Abdul',
#      u'Abo3abd',
#      u'Aboda901',
#      u'Accord 2.4 GHz',
#      u"Ada's Staff",
#      u"Adam's Wi-Fi Network",
#      u'Adam-Joni',
#      u'Admiral',
#      u'AdotBURR',
#      u'AdventureTimeSlow',
#      u'Ahmad-2.4',
#      u'Alcatel LINKZONE 5293',
#      u"Alicia's Wifi",
#      u'Alta1',
#      u'Alta1-guest',
#      u'Amaryllis',
#      u'Amazon WiFi',
#      u'Americanlife',
#      u'Ancient Grounds',
#      u'Angel',
#      u'Angels-2.4',
#      u'AngryMongol',
#      u"Anthony Kurdy's Network",
#      u'Apollonails',
#      u'Apollonails-guest',
#      u"Apple's Network",
#      u'Apptentive',
#      u'Apptentive Guest Network',
#      u'Apropos Salon & Barber (guest)',
#      u'Apt A',
#      u'Apt306-2',
#      u'Aquiesta',
#      u'Argosy-Corp',
#      u'Artefact',
#      u'ArtefactGuest',
#      u'Atlas03',
#      u'AtlasOnNet Free WiFi',
#      u'AtlasOnNet Free Wifi',
#      u'Audiochrome.a',
#      u'AvaWirelessApt',
#      u'Avenues Wellness',
#      u'Awesome',
#      u'Azn Kappa Psi',
#      u'Azuqua',
#      u'Azuqua-Guest',
#      u'B&B-Guest',
#      u'B-Test',
#      u'B9AQ-TWlzcyBMZWU',
#      u'BC-Guests',
#      u'BC-Wifi',
#      u'BHHS',
#      u'BHHS-GUEST',
#      u'BI 319',
#      u'BMPS1',
#      u'BMPSGuest',
#      u'BOS1206',
#      u'BWPioneerSquareHotel',
#      u'BabyBooBoo',
#      u'BacchusNet',
#      u'Bach_home',
#      u'Bacon',
#      u'Bad Internet',
#      u'Baldwin',
#      u'Banana Sand',
#      u'BarndawgCL',
#      u'Bartell Guest',
#      u'Bassetti Architects',
#      u'Bassetti Guest',
#      u'Bat Signal',
#      u'BatesMotel',
#      u'BearsRus',
#      u'BearsRusGuest',
#      u'Belkin.3A8C',
#      u'Bella',
#      u'Bellair2.4ghz',
#      u'Benaroya Hall',
#      u'Benaroya Hall Event',
#      u'Beren/2.4',
#      u'BevyUp_Guest',
#      u'Bicycles Allowed Full Lane',
#      u'Bifrost',
#      u'BigGeorge',
#      u'Bill Wi The Science Fi',
#      u'Bill Wi the Science Fi',
#      u'Bill_Wi_TheScience_Fi',
#      u'BirdsNest 2.4',
#      u'Bishop Bitches',
#      u'BlackMamba',
#      u'BlackMamba_2G',
#      u'BlackPugz',
#      u'BlackStallion1',
#      u'Black_Cat',
#      u'Blackcomb',
#      u'Blink Guest',
#      u'Blue Plate Digital',
#      u'Blue Swan',
#      u'BodyPoint',
#      u'BodyPoint Guest',
#      u'Bomquisha',
#      u'BorDilla',
#      u'Boy Wonder',
#      u'Br*911Ms',
#      u'Bradley Hill',
#      u'Broadstone Leasing',
#      u'Broderick',
#      u'BroncoBilly-G',
#      u'Bruce Willis 2.4',
#      u'Buddy',
#      u'Buffalo G',
#      u'Buffalo-G-9B20',
#      u'BuffaloG',
#      u'Bull Trouter',
#      u'Burgundy box 2.4',
#      u'Busa_HiFi',
#      u'Byrdhouse',
#      u'C+C-2017',
#      u'C+C-Guest',
#      u'CBCI-2B36-2.4',
#      u'CBCI-6AEE-2.4',
#      u'CBCI-6FD2-2.4',
#      u'CBCI-70AC-2.4',
#      u'CBCI-7A71-2.4',
#      u'CBCI-806D-2.4',
#      u'CBCI-84F5-2.4',
#      u'CBCI-86BD-2.4',
#      u'CBCI-92C6-2.4',
#      u'CBCI-92C6-5(2G)',
#      u'CBCI-9369-2.4',
#      u'CBCI-AC9F-2.4',
#      u'CBCI-BE54-2.4_EXT',
#      u'CBCI-BE5F-2.4',
#      u'CBCI-BE86-2.4',
#      u'CBCI-D233-2.4',
#      u'CBCI-D54D-2.4',
#      u'CBCI-DB87-2.4',
#      u'CBCI-E11C-2.4',
#      u'CBCI-E344-2.4',
#      u'CBCI-EC1E-2.4',
#      u'CBCI-F7E7-2.4',
#      u'CBCI-FFDA-2.4',
#      u'CBNet',
#      u'CG - Asus24',
#      u'CGN3-5B58',
#      u'CGN3-A7B8',
#      u'CGN3-FBF8',
#      u'CGNM-0398',
#      u'CGNM-0548',
#      u'CGNM-0A18',
#      u'CGNM-1F68',
#      u'CGNM-24D8',
#      u'CGNM-9A78',
#      u'CGNM-9AC8',
#      u'CGNM-D458',
#      u'CGNM-D558',
#      u'CGNM-E698',
#      u'CGNM-F288',
#      u'CGNVM-1E88',
#      u'CGNVM-3110',
#      u'CGNVM-EF00',
#      u'CGNVM-FC80',
#      u'CH',
#      u'CHRGUEST',
#      u'CHRINT',
#      u'CISecure',
#      u'CLG',
#      u'CLink2323_24',
#      u'CMA-WIFI',
#      u'CMD (public)',
#      u'CMDSEA',
#      u'CMTQWest',
#      u'COMCAST-WIFI',
#      u'COSMED1-2.4',
#      u'CPA',
#      u'CTU',
#      u'CableWiFi',
#      u'Cafe_AV',
#      u'Cafeku',
#      u'Caffe_Ladro',
#      u'Caio',
#      u'CalebRules',
#      u'Caliginous',
#      u'CampPrincessPartyCat',
#      u'Campbell2902',
#      u"CandY's House",
#      u'Canterbury',
#      u'Canterbury Guest-scanning',
#      u'Cappy',
#      u'Care+',
#      u'Carnitas',
#      u'CartmanBish',
#      u'CasaBarlita',
#      u'CasaDeLoco',
#      u'Casa_de_Collins',
#      u'CascadeStar',
#      u'Cascadelink Free Wifi',
#      u'Cascadelink308 2.4GHz',
#      u'Cascades',
#      u'Cascadia',
#      u'Cascadia Guest',
#      u'Cell 13',
#      u'Cell 13_EXT',
#      u'CellSpot_2.4GHz_A038',
#      u'CenturyLink0029',
#      u'CenturyLink0459',
#      u'CenturyLink0525',
#      u'CenturyLink0546',
#      u'CenturyLink0705',
#      u'CenturyLink0753',
#      u'CenturyLink0875',
#      u'CenturyLink1056',
#      u'CenturyLink1067',
#      u'CenturyLink1093',
#      u'CenturyLink1335',
#      u'CenturyLink1370',
#      u'CenturyLink1550',
#      u'CenturyLink1644',
#      u'CenturyLink1661',
#      u'CenturyLink1809',
#      u'CenturyLink1921',
#      u'CenturyLink1951',
#      u'CenturyLink1966',
#      u'CenturyLink2186',
#      u'CenturyLink2262',
#      u'CenturyLink2303',
#      u'CenturyLink2350',
#      u'CenturyLink2407',
#      u'CenturyLink2417',
#      u'CenturyLink2457',
#      u'CenturyLink2471',
#      u'CenturyLink2508',
#      u'CenturyLink2608',
#      u'CenturyLink2693',
#      u'CenturyLink2828',
#      u'CenturyLink2846',
#      u'CenturyLink2894',
#      u'CenturyLink3223',
#      u'CenturyLink3271',
#      u'CenturyLink3323',
#      u'CenturyLink3374',
#      u'CenturyLink3439',
#      u'CenturyLink3746',
#      u'CenturyLink3896',
#      u'CenturyLink4057',
#      u'CenturyLink4058',
#      u'CenturyLink4247',
#      u'CenturyLink4265',
#      u'CenturyLink4337',
#      u'CenturyLink4443',
#      u'CenturyLink4696',
#      u'CenturyLink4713',
#      u'CenturyLink4733',
#      u'CenturyLink4794',
#      u'CenturyLink4889',
#      u'CenturyLink4920',
#      u'CenturyLink5074',
#      u'CenturyLink5276',
#      u'CenturyLink5681',
#      u'CenturyLink5888',
#      u'CenturyLink6015',
#      u'CenturyLink6161',
#      u'CenturyLink6347',
#      u'CenturyLink6496',
#      u'CenturyLink6732',
#      u'CenturyLink6742',
#      u'CenturyLink6838',
#      u'CenturyLink7023',
#      u'CenturyLink7119',
#      u'CenturyLink7166',
#      u'CenturyLink7191',
#      u'CenturyLink7771',
#      u'CenturyLink8182',
#      u'CenturyLink8247',
#      u'CenturyLink8380',
#      u'CenturyLink8578',
#      u'CenturyLink8798',
#      u'CenturyLink8935',
#      u'CenturyLink9077',
#      u'CenturyLink9175',
#      u'CenturyLink9273',
#      u'CenturyLink9284',
#      u'CenturyLink9287',
#      u'CenturyLink9288',
#      u'CenturyLink9788_EXT',
#      u'CenturyLinkFieldWiFi',
#      u'Cequint',
#      u'CequintCorp',
#      u'Cerebro',
#      u'Ceres_Station',
#      u'Chan',
#      u'Chappie',
#      u'Charliebucket2',
#      u'ChateauRomani',
#      u'Cherry',
#      u'Chicken_2.4GHz_530186',
#      u'Chicken_Guest',
#      u'Chiyon',
#      u'Chromecast6853',
#      u'Chungees WiFi (Use this one)',
#      u'CiscoA5122',
#      u'City Paws Wi-Fi Network',
#      u'CityView3',
#      u'ClickClickClickClickClick',
#      u'ClickHereForPorn',
#      u'Clink-1818',
#      u'CloseQuarters',
#      u'CloudCatcher',
#      u'ClubNiaNPhia',
#      u'CocobearN',
#      u'CodeUL-SEA',
#      u'Cody Ulrich Studio 2.4ghz',
#      u'Colette',
#      u'Collins_Google',
#      u'Collins_Guest',
#      u'Concord',
#      u'Concord-guest',
#      u'Condo 1',
#      u'Contour',
#      u'ContourGuest',
#      u'Corbin Net',
#      u'Coruscant',
#      u'Cosmo Zodiac',
#      u'CostaWifi',
#      u'Curtis',
#      u'Cypher2100_ASUS',
#      u'D-NET-BLUE_2.4GHz',
#      u'D937',
#      u'DBFCellSpot_2.4GHz_B910',
#      u'DBGuest',
#      u'DBZ',
#      u'DCHQ-1',
#      u'DDseaOFF',
#      u'DELRIDGE DELI/CENTURNYLINK',
#      u'DG1670A22',
#      u'DINE2_11ng',
#      u'DIRECT-21-HP OfficeJet 4650',
#      u'DIRECT-21-HP OfficeJet Pro 8740',
#      u'DIRECT-40-HP Officejet 5740',
#      u'DIRECT-4480D08F',
#      u'DIRECT-47-HP OfficeJet 4650',
#      u'DIRECT-5A-HP OfficeJet 4650',
#      u'DIRECT-7C-HP ENVY 4520 series',
#      u'DIRECT-80-HP ENVY 7640 series',
#      u'DIRECT-86-HP OfficeJet Pro 6970',
#      u'DIRECT-8C78FD2C',
#      u'DIRECT-9A-HP ENVY 5540 series',
#      u'DIRECT-A5-HP ENVY 7640 series',
#      u'DIRECT-A6-HP ENVY 4520 series',
#      u'DIRECT-A6-HP Officejet 5740',
#      u'DIRECT-D4-HP ENVY 4520 series',
#      u'DIRECT-DF-HP Officejet 5740',
#      u'DIRECT-EC-HP OfficeJet Pro 8720',
#      u'DIRECT-F6-HP OfficeJet 3830',
#      u'DIRECT-TL-VIZIOTV',
#      u'DIRECT-r2Bartleby',
#      u'DJC_private',
#      u'DNDA Office',
#      u'DOLANRF',
#      u'DS_CORP',
#      u'DYSTNCT',
#      u'DaKoTa',
#      u'DaisyNMichael1',
#      u"Daniel's Wifi_EXT",
#      u'Daniels204',
#      u"Darling's Airport Network",
#      u'DatLumpia',
#      u'DaveBembridge-Guest',
#      u'Death Star',
#      u'Deep Thought',
#      u'DenonSmokeTest-FL',
#      u"Dexter's Lab",
#      u'Dexter3',
#      u"Dian's Wi-Fi Network",
#      u'Diesel',
#      u'Dirksen',
#      u'DiscoNap',
#      u'Discovery-Guest',
#      u'DiscoveryInst',
#      u'DjamilovaLaw',
#      u'Doctor_Who?1000',
#      u'DonkeyKing-guest',
#      u"Driver's iPhone",
#      u'Drogo',
#      u'Duggan',
#      u'Dvorak',
#      u'E Works',
#      u'EBD14911-PE8EkCqKaH09Otn',
#      u'EDGE-guest',
#      u'EMI Guest',
#      u'EMI Wireless',
#      u'EOMD',
#      u'ERD_Guest',
#      u'ERMAHGERD! WIERFIER',
#      u'EVO606',
#      u'EVSWines',
#      u'EWorks Guest',
#      u'Eagle Mike',
#      u'EastJohn',
#      u'Efelle Guest',
#      u'Efelle Team',
#      u"Elizabeth's iPhone",
#      u'Ellipsis Jetpack 8AC5',
#      u'ElusiveFresh',
#      u'Enterprise guest',
#      u'Ephspride',
#      u'EpicSeats Guest',
#      u'Epicodus Alumni',
#      u'Epicodus Staff',
#      u'Epicodus Students',
#      u'Etworknay',
#      u'Evans 2.4',
#      u'EyesOY',
#      u'EyesOnYou',
#      u'FBI Surveillance Van',
#      u'FCARTA29-2.4G-Guest',
#      u'FHDental',
#      u'FINERIE',
#      u'FINERIE-MAIN',
#      u'FIRESTATION36',
#      u'FIRSTGARDEN',
#      u'FLUTTER_2',
#      u'FLUTTER_Guest',
#      u'FMinternal',
#      u'FORMA 1st AVE',
#      u"FRANCESCA A MACK's Guest Network",
#      u"FRANCESCA A MACK's Network",
#      u'Fabriform Guest',
#      u'FadoSEA',
#      u'Falcon',
#      u'FastNet24',
#      u'FastNet24-Guest',
#      u'FekiFarm-2.4',
#      u'Felix',
#      u'Ffc16',
#      u'Fijate',
#      u'Firehouse-2.4',
#      u'FizzleInDaBuilding',
#      u'Fleet Corporate',
#      u'Fletch2.4',
#      u'Floor13',
#      u'FlowersOn15th',
#      u'FlyingSalami206',
#      u'FocalPLLC1',
#      u'Focke',
#      u'ForEva',
#      u'Formative (internal)',
#      u'Formative Guest',
#      u'ForwardThrust',
#      u'Foster Pepper',
#      u'Foundry Extreme',
#      u'Frandwork',
#      u'Free Cascadelink Wifi',
#      u'Free Public Wi-Fi',
#      u'FreeCat4U',
#      u'FreeViruses',
#      u'Frizznet',
#      u'FuckDonaldTrump',
#      u'Fuji',
#      u'Fun Closet',
#      u'G93',
#      u'GDS',
#      u'GDS-Guests',
#      u'GEISNESS_Private',
#      u'GETBENT',
#      u'GGLO Corp',
#      u'GGLO Wifi',
#      u'GGWP',
#      u'GHCF Guest',
#      u'GHCF Staff',
#      u'GPA-Guest',
#      u'GRINternet',
#      u'GT002807_Network',
#      u'GTAW',
#      u'Gabarama',
#      u'Game of wifis-guest',
#      u'Gameporium Office',
#      u'Garage',
#      u'Garth',
#      u'Gatorade',
#      u'GeorgeCell',
#      u'Ghanu!',
#      u'GhostFire',
#      u'GiantDumpster24',
#      u'GiantPigeon',
#      u'Gilmartin',
#      u'GoAway',
#      u'GoBlue2',
#      u'GoFarAway',
#      u'GoFish',
#      u'GoRobots',
#      u'GoldenLasso',
#      u'GoldenStateWarriors',
#      u'Good Pussy',
#      u'Good Pussy_EXT',
#      u'Gooddeed',
#      u'Google Starbucks',
#      u'Gordie Howe',
#      u'Grab-Guest',
#      u'Gracey Wi-Fi',
#      u'Greece',
#      u'Green WiFi',
#      u"Greg's iPhone",
#      u'Greyson',
#      u'Grimmauld Place',
#      u'GristGuest',
#      u'GristSecure',
#      u'Guest',
#      u'Guest SSID',
#      u'Guest Wifi',
#      u'Guest-2.4',
#      u'GuestWifi',
#      u'Guest_BYOD',
#      u'Gushiken',
#      u'HAGEN_2016',
#      u'HAINGUYEN-HP_Network',
#      u'HAINGUYEN-HP_Network_Ext',
#      u'HAWK of NIGHTO',
#      u'HEEYI',
#      u'HEIM',
#      u'HEYNOW',
#      u'HHM',
#      u'HOME',
#      u'HOME-0035-2.4',
#      u'HOME-0175-2.4',
#      u'HOME-0363-2.4',
#      u'HOME-0511-2.4',
#      u'HOME-061F',
#      u'HOME-0CB2',
#      u'HOME-0CBC-2.4',
#      u'HOME-0F95-2.4',
#      u'HOME-1438',
#      u'HOME-1732',
#      u'HOME-1A17-2.4',
#      u'HOME-1D87-2.4',
#      u'HOME-1E28-2.4',
#      u'HOME-2064',
#      u'HOME-2069-2.4',
#      u'HOME-20B2',
#      u'HOME-224C',
#      u'HOME-232E',
#      u'HOME-2A92',
#      u'HOME-2C78-2.4',
#      u'HOME-2CBB-2.4',
#      u'HOME-2D3E-2.4',
#      u'HOME-2EEF-2.4',
#      u'HOME-303F-2.4',
#      u'HOME-30F0-2.4',
#      u'HOME-32D2',
#      u'HOME-3624-2.4',
#      u'HOME-4342',
#      u'HOME-4406-2.4',
#      u'HOME-447C-2.4',
#      u'HOME-4677-2.4',
#      u'HOME-46EC-2.4',
#      u'HOME-4A56-2.4',
#      u'HOME-4AC9-2.4',
#      u'HOME-4BE2',
#      u'HOME-4E34-2.4',
#      u'HOME-5345-2.4',
#      u'HOME-55D9',
#      u'HOME-5712',
#      u'HOME-5833-2.4',
#      u'HOME-5898-2.4',
#      u'HOME-59F2',
#      u'HOME-5D6A-2.4',
#      u'HOME-5D9F',
#      u'HOME-5E42',
#      u'HOME-5F46-2.4',
#      u'HOME-5F4D-2.4',
#      u'HOME-622E-2.4',
#      u'HOME-6452',
#      u'HOME-6462',
#      u'HOME-6462_EXT',
#      u'HOME-6522',
#      u'HOME-68D2',
#      u'HOME-6DFE-2.4',
#      u'HOME-71BD-2.4',
#      u'HOME-7466-2.4',
#      u'HOME-770C',
#      u'HOME-80B2',
#      u'HOME-8914-2.4',
#      u'HOME-8A12',
#      u'HOME-8AB7-2.4',
#      u'HOME-8ADB-2.4',
#      u'HOME-8B02',
#      u'HOME-8B33-2.4',
#      u'HOME-8B64',
#      u'HOME-8B8F',
#      u'HOME-9152',
#      u'HOME-94B8-2.4',
#      u'HOME-973E-2.4',
#      u'HOME-98D5',
#      u'HOME-9B35-2.4',
#      u'HOME-9B99-2.4',
#      u'HOME-9C02',
#      u'HOME-9C20-2.4',
#      u'HOME-9C8D-2.4',
#      u'HOME-9C8D-2.4_2GEXT',
#      u'HOME-9D91',
#      u'HOME-9E72',
#      u'HOME-9F12',
#      u'HOME-9F32',
#      u'HOME-A597',
#      u'HOME-A7E5-2.4',
#      u'HOME-A82C-2.4',
#      u'HOME-AAC2',
#      u'HOME-B162',
#      u'HOME-B4A2_EXT',
#      u'HOME-B512',
#      u'HOME-B7B9-2.4',
#      u'HOME-BA32',
#      u'HOME-BA47',
#      u'HOME-BB65-2.4',
#      u'HOME-BBD2',
#      u'HOME-C8BB-2.4',
#      u'HOME-CB72',
#      u'HOME-D062',
#      u'HOME-D0A2',
#      u'HOME-D0ED-2.4',
#      u'HOME-D152',
#      u'HOME-D314-2.4',
#      u'HOME-D4B9-2.4',
#      u'HOME-D712',
#      u'HOME-D77F-2.4',
#      u'HOME-D94A-2.4',
#      u'HOME-DDAA-2.4',
#      u'HOME-E098',
#      u'HOME-E1D8-2.4',
#      u'HOME-E72A-2.4',
#      u'HOME-EBD2-2.4',
#      u'HOME-EED3-2.4',
#      u'HOME-F1C2',
#      u'HOME-F343-2.4',
#      u'HOME-F669-2.4',
#      u'HOME-F913-2.4',
#      u'HOME-FE3B-2.4',
#      u'HOMEAAD2',
#      u'HOTSYTOTSY',
#      u'HP-Print-06-Officejet Pro 8600',
#      u'HP-Print-0E-Photosmart 5520',
#      u'HP-Print-11-ENVY 4500 series',
#      u'HP-Print-16-LaserJet Pro M201dw',
#      u'HP-Print-34-Photosmart 5520',
#      u'HP-Print-37-Officejet Pro 8620',
#      u'HP-Print-43-Officejet Pro 8610',
#      u'HP-Print-4F-Officejet Pro 8600',
#      u'HP-Print-50-Officejet Pro 8610',
#      u'HP-Print-51-Photosmart 6520',
#      u'HP-Print-6D-Officejet Pro 8620',
#      u'HP-Print-6E-Photosmart 5520',
#      u'HP-Print-78-Photosmart 6520',
#      u'HP-Print-7B-Officejet 4630',
#      u'HP-Print-86-Photosmart 6520',
#      u'HP-Print-99-ENVY 5530 series',
#      u'HP-Print-A2-LaserJet Pro MFP',
#      u'HP-Print-AF-Officejet Pro 8610',
#      u'HP-Print-AF-Officejet Pro 8620',
#      u'HP-Print-C1-Photosmart 7520',
#      u'HP-Print-C6-Photosmart 6520',
#      u'HP-Print-C8-Officejet Pro 8630',
#      u'HP-Print-CC-Officejet 6700',
#      u'HP-Print-D4-LaserJet Pro MFP',
#      u'HP-Print-D9-Deskjet 2540 series',
#      u'HP-Print-DA-Photosmart 5520',
#      u'HP-Print-E8-Officejet Pro 8620',
#      u'HP-Print-F2-Officejet 7610',
#      u'HP-Print-F7-Officejet Pro 8610',
#      u'HP-nomodel.D081B6',
#      u'HP029E92',
#      u'HP8D10FF',
#      u'HP8EA188',
#      u'HPCP1525-1b3681',
#      u'HPD110a.87FAB0',
#      u'HPEE5533',
#      u'HPJ310a.F6DC87',
#      u'HPJ610a.09C67C',
#      u'HRDC-Guest',
#      u'HSE1901',
#      u'HSE423',
#      u'HSE519',
#      u'HSE903',
#      u'HSW1004',
#      u'HSW1510',
#      u'HSW304',
#      u'HUGHMUNGUS.NET',
#      u'Haggis-World 2',
#      u'Halgrim',
#      u'Hammertime2',
#      u'HappyEndings',
#      u'Happyhorse',
#      u'Happyhorse_Guest',
#      u'Harrison201 Wi-Fi Network',
#      u'HarrisonHouse',
#      u'HashtagPSL',
#      u'Hat Boutique',
#      u'Haus Homo',
#      u'Heartbeat',
#      u'HeatherWireless',
#      u'HeatherWireless-Extend',
#      u'Hello for ever',
#      u'Henrietta',
#      u'HenrySanchezReturnsAgain',
#      u'Hermes',
#      u'Higuera',
#      u'HildawgForPrez',
#      u'HilltopService',
#      u'HoldTheDoor',
#      u'Holman',
#      u'Home Network',
#      u'HomeStay',
#      u'HomeStayDownStairs',
#      u"Hong's Lux",
#      u'Hopvine_Private',
#      u'HorseDivorce',
#      u'Hot lava ouch',
#      u'Hotel Mezz',
#      u'HowardOutpost',
#      u'Hurlow',
#      u'HyperboleAAH',
#      u'I Cast Zone of Truth',
#      u'I Hate Comcast',
#      u'IBR1100-540',
#      u'IE Lab - Combo Net',
#      u'IE Lab WiFi',
#      u'ISK',
#      u'ISK-Guest',
#      u'IUNUIT2.4',
#      u'IceCream_Guest',
#      u'IdeoClick',
#      u'Ingram2.4',
#      u'InterGalactic-2.4',
#      u'IsThisKrustyKrab',
#      u'IslandGirl-2.4',
#      u'IslandLife',
#      u'ItalianFamilyPizza',
#      u'Ivanti-Guest',
#      u'JAG082824',
#      u'JEBB-UP',
#      u'JG1',
#      u'JLLBOA-Guest',
#      u'JLLBOA-WIFI',
#      u'JM Heezy 2.4gHz',
#      u'JONATHAN-PC_Network',
#      u'JP_2.4',
#      u'JRDG',
#      u'JUMA',
#      u'JYB Seattle Home',
#      u'JadeGardenWS',
#      u'Jail',
#      u'JamesK',
#      u'Jan-2.4',
#      u'Janet-2.4',
#      u'Jc',
#      u'Jelly',
#      u'Jersey11',
#      u'JimClarkMarina',
#      u'JonathonLee',
#      u'Jookie',
#      u'Josh Williams\\xE2..s iPhone',
#      u'Josh3',
#      u'JuliaRose',
#      u'Juniper Ascending',
#      u'K7 1463',
#      u'KAS',
#      u'KCPublic',
#      u'KMP Guest',
#      u'KOKO',
#      u'KRB_NET',
#      u'KTC Guest',
#      u'K_WiFi_Netz_2.4',
#      u'Kashru',
#      u'KayKat',
#      u'KenSci',
#      u'Kenneth-Konrad',
#      u'Khaleesi',
#      u'KimJongIllmatic',
#      u'Kitchen Home.k',
#      u'Kizuki_Izakaya',
#      u'Klaus_WiFi',
#      u'Kodmans',
#      u'Komodo2',
#      u'KrissyAndJustin',
#      u'Kruse_WiFi_bgn',
#      u'Kuulei',
#      u'L4-2.4',
#      u'L4Guest',
#      u'L4Mobile',
#      u'LAN Before Time',
#      u'LANbeforetime',
#      u'LBP',
#      u'LBP Guest',
#      u"LC's Guest Network",
#      u"LC's Wi-Fi Network",
#      u'LCARS 2.4',
#      u'LIMI',
#      u'LLF',
#      u'LLF-Guest',
#      u'LOFT',
#      u'LOL',
#      u'LOL-guest',
#      u'LOSO',
#      u'LWD',
#      u'Lady Treasure',
#      u'Laptop2',
#      u'Larson',
#      u'Last Dance',
#      u'LauraHome',
#      u'Laurel',
#      u'Law Office of Leary & Wagnlid',
#      u'Lazenby N',
#      u'LeCedrus',
#      u'Leafly',
#      u'LeaflyGuest',
#      u'LexxinWland',
#      u'Li Law',
#      u'Liberty Bar',
#      u'Linedata',
#      u'Linksys00140',
#      u'Linksys00140-guest',
#      u'Linksys05982',
#      u'Linksys11785',
#      u'Linksys16557-guest',
#      u'Linksys19737',
#      u'Linksys22160',
#      u'LinksysSMB24G',
#      u'Linksys_2GHz',
#      u'Linuxfood.net',
#      u'LionHome',
#      u'LiteShow3',
#      u'LittlePlanet',
#      u"Liv's Wi-Fi Network",
#      u'LjLr11',
#      u'LjLr511',
#      u'Lodge_2GEXT',
#      u'LofMC',
#      u'LokiLikesLucy',
#      u'Lokijo3-2.4',
#      u'Love Net',
#      u'LoveCouch',
#      u'LoveCouch_EXT',
#      u'LowT99',
#      u'Luckey24',
#      u'Lucky Fish',
#      u'M3dDev',
#      u'M4_SEA',
#      u'M4m786iA',
#      u'MAD-PIZZA-2.4',
#      u'MAXWIFI',
#      u'MB Hotspot 6446549',
#      u'MB WLAN 24344',
#      u'MESA',
#      u'MIER',
#      u'MINIONS!',
#      u'MIWIGuest',
#      u'MLaw',
#      u'MM Guest',
#      u'MMFS_Shared',
#      u'MMWK',
#      u'MNSEA',
#      u'MNSEA-AV',
#      u'MOTOC8C2',
#      u'MOTOROLA-125BC',
#      u'MOTOROLA-DBE35',
#      u'MP Meraki Lab',
#      u'MP2Wifi',
#      u'MR_MEESEEKS',
#      u'MS_HI_WLAN',
#      u'MT Engineer WiFi',
#      u'MUUFFFINNNNNSSSSSS',
#      u'MY SIN',
#      u'MYLM',
#      u'MacAttack',
#      u'Macy1234',
#      u'Madrona Guest',
#      u'MaePhimThaiResteraunt',
#      u"Maggie's Wi-Fi Network",
#      u'Magical Motherfucker',
#      u'Mahlum WiFi',
#      u'Mandm',
#      u'Manurism',
#      u'Maple Apartments',
#      u'Maple Apartments Back',
#      u'Marayart',
#      u'Margaretland',
#      u'Maria58',
#      u"Marilyn's Wi-Fi Network",
#      u'Marinab',
#      u"Mario's ALCHEMIE Wi-Fi Network",
#      u"Mary's Wi-Fi Network",
#      u'Maxi',
#      u'Melange',
#      u'Menedo_Network_2',
#      u'Mercuryclub1',
#      u'Michelle',
#      u'Michelle-2.4',
#      u'Mikey_Man_2',
#      u'Mikey_Man_4',
#      u'Mikey_Man_5',
#      u'Mikey_Man_7',
#      u'Mikey_man',
#      u'Millheads_2GEXT',
#      u'MobileTerm',
#      u'ModeMusic',
#      u'Moist Porpoise',
#      u"Molly's Network",
#      u'Molokai',
#      u'MomentHQ2.4',
#      u'Monsters Inc',
#      u'Moo',
#      u'MoonSnail4031',
#      u'Moonraft-2.4',
#      u'MoruN',
#      u'MuakaSlow',
#      u'Mugwort',
#      u'NCH2117',
#      u'NETGEAR',
#      u'NETGEAR-Guest',
#      u'NETGEAR02',
#      u'NETGEAR05',
#      u'NETGEAR09',
#      u'NETGEAR10',
#      u'NETGEAR11',
#      u'NETGEAR12',
#      u'NETGEAR13',
#      u'NETGEAR14',
#      u'NETGEAR15',
#      u'NETGEAR16',
#      u'NETGEAR16_EXT',
#      u'NETGEAR18',
#      u'NETGEAR21',
#      u'NETGEAR22',
#      u'NETGEAR23',
#      u'NETGEAR24',
#      u'NETGEAR25',
#      u'NETGEAR26',
#      u'NETGEAR27',
#      u'NETGEAR28',
#      u'NETGEAR29',
#      u'NETGEAR30_EXT',
#      u'NETGEAR31',
#      u'NETGEAR32',
#      u'NETGEAR32_Ext',
#      u'NETGEAR33',
#      u'NETGEAR36',
#      u'NETGEAR37',
#      u'NETGEAR41',
#      u'NETGEAR41-arlo_247028',
#      u'NETGEAR44',
#      u'NETGEAR46',
#      u'NETGEAR48',
#      u'NETGEAR52',
#      u'NETGEAR53',
#      u'NETGEAR55',
#      u'NETGEAR60',
#      u'NETGEAR62',
#      u'NETGEAR63',
#      u'NETGEAR66',
#      u'NETGEAR67',
#      u'NETGEAR68',
#      u'NETGEAR69',
#      u'NETGEAR70',
#      u'NETGEAR71',
#      u'NETGEAR72',
#      u'NETGEAR73',
#      u'NETGEAR74',
#      u'NETGEAR75',
#      u'NETGEAR76',
#      u'NETGEAR77_RE',
#      u'NETGEAR80',
#      u'NETGEAR81',
#      u'NETGEAR83',
#      u'NETGEAR84',
#      u'NETGEAR86',
#      u'NETGEAR87',
#      u'NETGEAR89',
#      u'NETGEAR89-arlo_247024',
#      u'NETGEAR92',
#      u'NETGEAR93',
#      u'NETGEAR94',
#      u'NETGEAR95',
#      u'NETGEAR96',
#      u'NG1',
#      u'NKPS',
#      u'NKPS-GUEST',
#      u'NLISEA2',
#      u'NTGR_VMB_1041408741',
#      u'NTGR_VMB_1462060932',
#      u'NW-MESH-2412',
#      u'NWCC',
#      u'NWDR',
#      u'NachoWiFi',
#      u'NamelessGrave',
#      u'Nate&Kate',
#      u'NatureConsortium',
#      u'NatureConsortium-Guest',
#      u'Neon_Genesis_Evangelion',
#      u'Nguyen',
#      u'No_Justice_On_Stolen_Land',
#      u'No_Justice_On_Stolen_Land1',
#      u'Norma',
#      u'NorwaySweden85',
#      u'NumeraPrivate',
#      u'NumeraPublic',
#      u'OLSENMDINCPS',
#      u'OLYMPIAPIZZA3',
#      u'ORBI64',
#      u'Ocean Nail & Spa',
#      u'OchoaCenturyLink',
#      u'OchoaCenturyLink_EXT',
#      u'Oliver-2.4',
#      u'OnSite Admin',
#      u'OnSite WiFi',
#      u'Orbit',
#      u'Orbital',
#      u'Orderflowers2064675549',
#      u'OrlinGuest',
#      u'OuncesGuest',
#      u'P1212',
#      u'PCI',
#      u'PCS-Corp',
#      u'PCS-Guest',
#      u'PHONETAP',
#      u'PIUS',
#      u'PMI Hotspot',
#      u'PMI_internal',
#      u'PMX',
#      u'PNWF_PUBLIC',
#      u'PNWFertility',
#      u'PRY-SBG',
#      u'PS4-229A3A04A857',
#      u'PS4-234C537ABE6F',
#      u'PS4-CCC5968C0BE6',
#      u'PSF-WEST-BAY',
#      u'PSMHS0130',
#      u'PSRCW-Guest',
#      u'Pacterm',
#      u'Paincave',
#      u'Pakbaz',
#      u'PalermoSeattle',
#      u'Pando Guest',
#      u'Panopto Guest',
#      u'Password_is_taco',
#      u'PayScaleGuest',
#      u'Payscale',
#      u'PearlJu',
#      u'PearlsAndSquids',
#      u'Pegasus',
#      u'Pelican Stay 506',
#      u'Penguin_Wifi',
#      u'Pensar AV',
#      u'Perkins-Guest-WiFi',
#      u'PhilipsDDS1',
#      u'PhilipsDDS2',
#      u'PhoSaigon',
#      u'Picture Properties 2',
#      u'Pierre_Lauren',
#      u'Piggy',
#      u'Pikachu',
#      u'Piperelli',
#      u'Plato_WN24_EXT',
#      u'Pleasant Ridge',
#      u'PleaseHammerDontHurtEm',
#      u'Polly',
#      u'Port Jason',
#      u'PowerPacketPasser513',
#      u'PrettyFlyforaWi-fi',
#      u'PrimeN',
#      u'Primus',
#      u'Private WiFi Default',
#      u'Private313',
#      u'Projector',
#      u'Psychic Recovery Institute 2.4G',
#      u'Public1',
#      u'Pumpkin_2G_EXT',
#      u'Putabirdonit',
#      u'Quiet',
#      u'R2-D2',
#      u'RAINBOW',
#      u'RAWR EXTREME',
#      u'RBSP',
#      u'RCS-Guest',
#      u'RCS-Int',
#      u'RCT',
#      u'RDDNET2.4',
#      u'RFT46',
#      u'RIP America',
#      u'RMN684',
#      u'RPH SES iPhone',
#      u'RadicalMajik69',
#      u'Radically-Distinct',
#      u'Radio Free Zerg',
#      u'RainierEndo',
#      u'RainierEndoGuest',
#      u"Rajni's iPhone",
#      u'RapidRide',
#      u'Ray',
#      u"Reba's Wi-Fi Network",
#      u'Red Balloon Company',
#      u'ReenyChris',
#      u'Remedy Teas 1',
#      u'Renaissance_CONFERENCE',
#      u'Renaissance_GUEST',
#      u'Renaissance_PUBLIC',
#      u'RiaMirchi',
#      u'RioneXIII',
#      u'RissMini',
#      u'Ristretto 2.4',
#      u'Roadability',
#      u'Roadhouse',
#      u'RobotWorld',
#      u'Rogue-2G',
#      u'RoomOfRequirement',
#      u'Rosa Le',
#      u'Ross Acadia',
#      u'Rudi',
#      u'Rudys Guest',
#      u'Rudys Office',
#      u'Rudys SS',
#      u'Rudys Tech',
#      u'Runberg',
#      u"Ryno's Ri-Fi Network",
#      u'S1411',
#      u'S24_206',
#      u'S24_406',
#      u'S5',
#      u'SAM Wi-fi',
#      u'SB Seattle',
#      u'SBG6700AC-D3BEB',
#      u'SBG6900AC-EAE3F',
#      u'SBG6900AC-EAFDB',
#      u'SC CAMS',
#      u'SCH-I5451A9D',
#      u'SCJ-RMP',
#      u'SEA SOAP-N',
#      u'SEAID8LAB',
#      u'SEASTEAMWLAN',
#      u'SEATTLE-DaNa',
#      u'SEA_CHASSIS_SHOP',
#      u'SEA_POWER_SHOP',
#      u'SEA_POWER_SUPPLY',
#      u'SEC_LinkShare_4df875',
#      u'SETUP',
#      u'SGH2',
#      u'SGSPartners',
#      u'SGS_Wireless',
#      u'SISNWINC',
#      u'SJS Private 2.4',
#      u'SM-J700P556',
#      u'SM-N900V2EC8',
#      u'SMCIN01',
#      u'SORRIDA',
#      u'SPB-Guest',
#      u'SR520-WF',
#      u'SRQ0',
#      u'SRQ12',
#      u'SSA_T18',
#      u'SSC',
#      u'SSID3',
#      u'SSID4',
#      u'SSL-Secured',
#      u'STRAIGHTJACKET Wifi Booster',
#      u'STRONGHOLD',
#      u'Saigon-office',
#      u'SalsaVerde',
#      u'SalvadorDali',
#      u'Samsung Galaxy Express 3 9982',
#      u'Samsung Galaxy S III 67',
#      u'Samsung Galaxy S6 8060',
#      u'Sandi Wireless',
#      u'Sansaire',
#      u'SargentLaw',
#      u'Sasha15',
#      u'Sassytown',
#      u'SchemingSchemes',
#      u'School of Rock_EXT',
#      u'Science of Life 2',
#      u'ScilliBonInc',
#      u"ScottieYahtzee's Ice Palace WiFi",
#      u'SeAnCaLink',
#      u'SeafarerCenter2',
#      u'Seahawks Regular Season MVP',
#      u'Seahawks88',
#      u'SeaportShopZ',
#      u'Seattle Public WIFI',
#      u'Seattle_TL_Yard',
#      u'Seattle_WiFi',
#      u'Secret Sausage Office',
#      u'Sentinel',
#      u'Serenity',
#      u'Setty',
#      u'ShaggingChateau',
#      u'Short',
#      u'Silverware-DLINK',
#      u'SkiRN',
#      u'SkillShowwifi',
#      u'Skin Surgery Center Guest',
#      u'Sky View',
#      u'SkyviewCa',
#      u'Slalom Guest',
#      u'Slalom IoT',
#      u'Slonik',
#      u'SlothKingdom',
#      u'Smith and Dawn 2 Wi-Fi Network',
#      u"Sol's Rays",
#      u'Sorrento-Event',
#      u'Sounders-FC',
#      u'Sparrow',
#      u'Special Agent Dale Cooper',
#      u'SpecialtysFreePublicWiFi',
#      u'Spices',
#      u'Spinnersend',
#      u'SpringThyme',
#      u'SprintGateway-4E8',
#      u'SprintGateway-4E8-R2',
#      u'SprintWiFia-23F6D7',
#      u'SprintWiFia-24D83C',
#      u'SprintWs',
#      u'Sshhhhh',
#      u'StPete2',
#      u'StadiumAV',
#      u'StarWars2.4',
#      u'Stay Alfred',
#      u'Stay Alfred Harbor Steps',
#      u'StemperWifi',
#      u'Stoptrump2.4',
#      u'Stratton-2.4',
#      u'Stryker',
#      u'Studio302',
#      u'StudioRadSauce',
#      u'Succor? I hardly know her!',
#      u'Sugar Bakery',
#      u'Sundsted',
#      u'Superman',
#      u'SureCriticAP',
#      u'Swedish',
#      u'SymbioteNano',
#      u'T*ni#36!',
#      u'T-Mobile Broadband06',
#      u'T-Mobile Broadband52',
#      u'T-Mobile Broadband52_EXT',
#      u'T18_Yard',
#      u'TCRadius',
#      u'TCUCornDogs',
#      u'TERRY_N',
#      u'TEST-WAP',
#      u'TESTBENCH-GW',
#      u'TFC-Blue',
#      u'TFC-Guest',
#      u'TLF_GUEST',
#      u'TLF_INTERNAL',
#      u'TOP-POT',
#      u'TP Link 2.4G',
#      u'TP-LINK_1012',
#      u'TP-LINK_1319',
#      u'TP-LINK_1892',
#      u'TP-LINK_1CFA',
#      u'TP-LINK_1D46',
#      u'TP-LINK_2.4GHz_07FA59',
#      u'TP-LINK_2.4GHz_080215',
#      u'TP-LINK_2.4GHz_090491',
#      u'TP-LINK_2.4GHz_56B1E9',
#      u'TP-LINK_2.4GHz_73485D',
#      u'TP-LINK_2.4GHz_AA0521',
#      u'TP-LINK_2.4GHz_BDF309',
#      u'TP-LINK_2.4GHz_FBFF15',
#      u'TP-LINK_2.4GHz_FC0189',
#      u'TP-LINK_22E3',
#      u'TP-LINK_2ACA',
#      u'TP-LINK_2FFA',
#      u'TP-LINK_3638',
#      u'TP-LINK_3CE1',
#      u'TP-LINK_456C',
#      u'TP-LINK_4B59',
#      u'TP-LINK_52368E',
#      u'TP-LINK_556568',
#      u'TP-LINK_5603',
#      u'TP-LINK_56C1',
#      u'TP-LINK_5DE9',
#      u'TP-LINK_5FFD',
#      u'TP-LINK_697A',
#      u'TP-LINK_69BC',
#      u'TP-LINK_6A35',
#      u'TP-LINK_6F1B',
#      u'TP-LINK_7831',
#      u'TP-LINK_7C3A',
#      u'TP-LINK_7F00',
#      u'TP-LINK_7FA5',
#      u'TP-LINK_7FB4',
#      u'TP-LINK_8663',
#      u'TP-LINK_88F0',
#      u'TP-LINK_8B8D',
#      u'TP-LINK_8CA1',
#      u'TP-LINK_93A58C',
#      u'TP-LINK_93E9',
#      u'TP-LINK_95A7',
#      u'TP-LINK_9854',
#      u'TP-LINK_9A3F',
#      u'TP-LINK_9BBF',
#      u'TP-LINK_9EB3',
#      u'TP-LINK_A207',
#      u'TP-LINK_A350',
#      u'TP-LINK_A4EB',
#      u'TP-LINK_A7B5',
#      u'TP-LINK_A909',
#      u'TP-LINK_AA2BAA',
#      u'TP-LINK_B183',
#      u'TP-LINK_B2DFCA',
#      u'TP-LINK_EA14',
#      u'TP-LINK_EC64',
#      u'TP-LINK_EE758E',
#      u'TP-LINK_Smart Plug_B214',
#      u'TP-Link_D6F8',
#      u'TRENDnet410_2.4GHz_30CB',
#      u'TSS',
#      u'TZKWXN1',
#      u'Taejontt',
#      u'TakeFive',
#      u'TandooriDiamond',
#      u"Tang's Wi-Fi Network",
#      u'TaxiLinQ_169_D4CA6E090375',
#      u'TaxiLinQ_499_D4CA6E095AD1',
#      u'Team Fishdick',
#      u'Tectonic 2.4 Ghz',
#      u'Tectonic Guest 2.4 Ghz',
#      u'Teenage mutant ninja turtles',
#      u'Terminal 7a',
#      u'Terminal_5',
#      u'TestWLan1',
#      u'Textio',
#      u'Thames-N',
#      u"That's Racist",
#      u'The Docking Station 2.4GHz',
#      u'The Force',
#      u'The House Stark',
#      u'The Internet',
#      u'The Interweb',
#      u'The LAN Before Time',
#      u'The Leakey Cauldron',
#      u'The Library',
#      u'The Lyric Mgmt',
#      u'The Newman Home',
#      u'The Office',
#      u'The Office Daily',
#      u'The Reckoner',
#      u'The Universe! 2.4g',
#      u'The Universe! 2.4g_EXT',
#      u'TheBerry',
#      u'TheCollective',
#      u'TheGoose',
#      u'TheHarrisonModern',
#      u'TheInternets-2',
#      u'TheKingAsus',
#      u'TheNest',
#      u'TheNetwork',
#      u'TheOKWIFI',
#      u'TheSilverFoxes',
#      u'TheThreeBroomSticks-2.4',
#      u'ThinMint',
#      u"Tian's Home",
#      u'TigersDen-2.4',
#      u'TildLink',
#      u'Tims-2.4',
#      u'Tinkerbell',
#      u'Tip Drill',
#      u'TkLrCp7',
#      u'TnC-2.4GHz Guest',
#      u'Toad-1',
#      u'TokLLC',
#      u'Tomorrow Fast',
#      u'Tomorrow Guest',
#      u'Tony',
#      u'Tootsieroll',
#      u'Transformational Unfolding',
#      u'Trap Castle',
#      u'TrapMansion',
#      u'Trevinohome',
#      u'Trianglepub',
#      u'Trinity Ext',
#      u'Trophy Husband',
#      u'TrueBenefits GUEST',
#      u'TrueBenefits PRIVATE',
#      u'TrustNoOne',
#      u'Tsunami05',
#      u'Tunnel WIFI',
#      u'Tuxera',
#      u'U R A',
#      u'UAC-03',
#      u'USCEvents',
#      u'USS Enterprise ncc 1701 z',
#      u'UWKC-Device',
#      u'UWKC-Guest',
#      u'UWKC-Staff',
#      u'UWKC-Wireless',
#      u'UnderwearParty2',
#      u'Unit501',
#      u'University Club',
#      u'UpsideMobile',
#      u'Uptown Gameporium Guest',
#      u'UptownDelridge',
#      u'UptownEspresso',
#      u'VCB',
#      u'VIKING9',
#      u'VM Home',
#      u'VacilandoBar-2.4',
#      u'Valyrian Steel',
#      u'Venom',
#      u'Verizon-890L-4027',
#      u'Verizon-MiFi6620L-9AEE',
#      u'Verizon-MiFi6620L-F46E',
#      u'Verizon-SM-G900V-C9CA',
#      u'Vertex Secure',
#      u'VickieATS',
#      u'Victrola Back Office',
#      u'Victrola Coffee',
#      u'Video_Link',
#      u'ViralAir',
#      u'Virus_Detected',
#      u'Visitor',
#      u'Vo De Thuong 2.4GHz',
#      u'VoNguyen',
#      u'VonsGuest-2',
#      u'VonsSecure-2',
#      u'WAGUEST',
#      u'WEYERWON2',
#      u'WM312dd7',
#      u'WSAH',
#      u'WSDOT-guest',
#      u'WSDOT-secure',
#      u'WSOPHighlinePT',
#      u'WSea Armory',
#      u'WUC1',
#      u'WUTANG',
#      u'Walgreens Guest WiFi',
#      u'Wallace Wireless',
#      u'Walton Open Guest',
#      u'WaveG Public WiFi',
#      u'Wave_89_2.4GHz',
#      u'Waxon1',
#      u'We have no wifi',
#      u'We-are-watching-you',
#      u'Weird_Guy',
#      u'Weirder',
#      u'Westeros',
#      u'Whathappen',
#      u'Wi-Fi Network1',
#      u'WiFi Hotspot 1108',
#      u'WiFi Hotspot 2460',
#      u'WiFi Hotspot 3409',
#      u'WiFi Hotspot 3977',
#      u'WiFi Hotspot 4531',
#      u'WiFi Hotspot 7017',
#      u'WiFi Hotspot 7263',
#      u'WiFi Hotspot 7458',
#      u'WiFi Hotspot 8937',
#      u'WiFight',
#      u'Wifi-Tang Clan',
#      u'Wilboneau',
#      u'Winchester_Network',
#      u'Wireless',
#      u'WorkLoft Building Wifi',
#      u'XFINITY',
#      u'XiaoChanChan',
#      u'XochisFlyWifi',
#      u'Xy34HH32',
#      u'YB!!!',
#      u'Youngstown',
#      u'Yowzas',
#      u'Yowzass',
#      u'Yuzi_WiFi',
#      u'Zoe',
#      u'Zumthor_2G',
#      u'\\x00',
#      u'\\x00\\x00',
#      u'\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u"\\xE5.\\xB4\\xE9.\\xA8\\xE8\\xB1\\xAA's iPhone",
#      u'\\xE6.\\xA0\\xE6..',
#      u'_Aluminum_Falcon_',
#      u'a wifi has no name',
#      u'abcTin',
#      u'amandine',
#      u'amaya chevy',
#      u'amber',
#      u'aname 2.4g',
#      u'animalcrackers_guests',
#      u'apartment',
#      u'apt6',
#      u'aqguest',
#      u'asus',
#      u'autonet-BE60',
#      u'babezeetin',
#      u'barry2.4',
#      u'bbx',
#      u'bbx East Marina Roof',
#      u'bd1890',
#      u'bearhome',
#      u'beberegis',
#      u'belkin.5af',
#      u'belkin.5af.guests',
#      u'belkin.6ee',
#      u'belkin.6ee.guests',
#      u'belkin.764.guests',
#      u'belkin.dbc',
#      u'belkin.de2.guests',
#      u'belkin.dee',
#      u'bf',
#      u'bird123',
#      u'bitstobolts',
#      u'bnsfyard',
#      u'burntdistrict',
#      u'caseyrose',
#      u'catdog',
#      u'catsrock',
#      u'ceq-corp-wlan',
#      u'chelseagrin',
#      u'chennaigals',
#      u'chicken',
#      u'chp_corp',
#      u'chp_guest',
#      u'chuck',
#      u'coastal-guest',
#      u'coleman1',
#      u'connector1011',
#      u'cornelius',
#      u'creamy creamy wifi',
#      u'cumulus',
#      u'czyrksys',
#      u'dan chevrolet',
#      u'daniela',
#      u'dc',
#      u'dexter2.4',
#      u'dhland pros',
#      u'disarraygun',
#      u'dlink-EA84',
#      u'dropbear',
#      u'easyjoes',
#      u'ebouton',
#      u'efsair',
#      u'enjoy your stay',
#      u'ergophobic1',
#      u'estrella',
#      u'et',
#      u'fefb4e53fe2e142938c4cbce4b4bc4bd',
#      u'ferry',
#      u'field of cheems',
#      u'fipsec',
#      u'formfollowsfunctionUK',
#      u'frieda',
#      u'fun&Flirti',
#      u'g-wifi',
#      u'g1',
#      u'g1-guest',
#      u'gluttony',
#      u'go huskies',
#      u'gordok',
#      u'gradpad',
#      u'guest_access',
#      u'guileless wireless',
#      u'h0m3l4n',
#      u'haystack',
#      u'hcc-guest',
#      u'hearts in sf',
#      u'hellokitty',
#      u'hhonors',
#      u'hithere',
#      u'hodge',
#      u'hoopburg',
#      u'houseofgeoff',
#      u'hpsetup',
#      u'iClan',
#      u'iOS_Mobile_2.4',
#      u'iPhone',
#      u'inBios Guest',
#      u'insectshield',
#      u'interwebs',
#      u'ipad only',
#      u'island-3151C0',
#      u'island-3DFF30',
#      u'jeffcap',
#      u'jenson',
#      u'jkenwil',
#      u'johnny',
#      u'johnny-guest',
#      u'jrdg',
#      u'jryry',
#      u'jumpkicks',
#      u'jv81385',
#      u'k4',
#      u'kerbzspark',
#      u'kickapoo',
#      u'kidane',
#      u'kiiiirk',
#      u'kimfamily',
#      u'king uzziah',
#      u'leisurewireless_EXT',
#      u'leopard',
#      u'lesisurewireless',
#      u'lgss24ghz',
#      u'linksys',
#      u'luckylan_24',
#      u'lunarnet',
#      u'mango ice cream',
#      u'mariners24',
#      u'medialink',
#      u'medialink_EXT',
#      u'mega',
#      u'mega-cafe',
#      u'melody',
#      u'meownet',
#      u'mkwireless',
#      u'molasses',
#      u'myqwest0123',
#      u'myqwest0135',
#      u'myqwest0136',
#      u'myqwest4701',
#      u'myqwest5346',
#      u'myqwest6451',
#      u'myqwest7452',
#      u'myqwest7711',
#      u'myqwest8587',
#      u'myqwest9793',
#      u'myqwest9985',
#      u'nachowireless',
#      u'neighbor',
#      u'ngHub_319441NB005CC',
#      u'ngHub_319451NX03090',
#      u'ngHub_319453NH00ABF',
#      u'nomad5',
#      u'northbound_guest',
#      u'northwest',
#      u'notYOmamashouse',
#      u'not_the_nsa',
#      u'nurses',
#      u'orderflowersnow2065882879',
#      u'ortolan',
#      u'othernetwork',
#      u'pacifica',
#      u'panopto-ad',
#      u'pantsoflivinglight',
#      u'patrick2',
#      u'penny 2.4',
#      u'perunet 3',
#      u'phoshizzle',
#      u'phscorp',
#      u'phsinternal',
#      u'phsmeddev',
#      u'phsmedical',
#      u'plug',
#      u'poof8',
#      u'portrait of the fat lady',
#      u'poswifi',
#      u'prasanth',
#      u'prov.employee',
#      u'purplegiant',
#      u'purplemonkey',
#      u'pushy mcshove',
#      u'qwest3776',
#      u'raincitynest',
#      u'rainisfalling',
#      u'rd3x',
#      u'ren_devices',
#      u'rkcdbp',
#      u'sYzYgY',
#      u'samstella',
#      u'sandhillcranes',
#      u'sbk',
#      u'schnecklecker',
#      u'scudder',
#      u'scuttlebutt',
#      u'searay',
#      u'seattle apt 2.4',
#      u'seattlebm',
#      u'serenity',
#      u'severok2',
#      u'shen2',
#      u'shenanigans',
#      u'silvercloud',
#      u'siwifi-cl',
#      u'siwifi-ng',
#      u'siwifi-ng-guest',
#      u'skylark',
#      u'skynet',
#      u'slacktide',
#      u'smelaku',
#      u'socket',
#      u'spacecadet',
#      u'spacetigers',
#      u'sstrossity',
#      u'stinkymobile',
#      u'store16',
#      u'storeseven-2.4',
#      u'studio18art',
#      u'suebee55',
#      u'sugarsugar',
#      u'supermonkeynobb',
#      u't18yard',
#      u'tamuning',
#      u'tando_EXT',
#      u'tango',
#      u'taniguchi1',
#      u'terry1',
#      u'test',
#      u'theblackstack-2.4',
#      u'thegroovesurfers',
#      u'theshopagora',
#      u'tl695558',
#      u'tla2bf10',
#      u'tonalli',
#      u'triangle',
#      u'triangle_guest',
#      u'umagat2.4',
#      u'unicorns suck',
#      u'v0cer@',
#      u'vendcust',
#      u'viknet',
#      u'vpnator',
#      u'waxon-smooth',
#      u'waywardwitch-2.4',
#      u'werock',
#      u'westerosg',
#      u'what is my purpose',
#      u'wireless2',
#      u'witech2',
#      u'woma',
#      u'wpa-wireless',
#      u'wsha1',
#      u'wwwnestegggcom',
#      u'xSouthWirelessNetwork',
#      u'xfinitywifi',
#      u'xray',
#      u'yourcrazyredhead',
#      u'yrneh09'])

# %%
# Same query, but for thing2
cursor = ap_collection.find({'host': 'thing2'})

essids = set()
for j,doc in enumerate(cursor):
    essids.add(doc['essid'])

print("Saw %d networks:"%(len(essids)))
pprint(essids)
# Out:
# Saw 361 networks:
# set([u'',
#      u'306',
#      u'358_GUEST',
#      u'5ECUR3w3p5TOR3',
#      u'8MKODPLI',
#      u'AG007',
#      u'ASUS_2.4_Mo',
#      u'ASUSofSpades2',
#      u'Alejandro',
#      u'Alias',
#      u'Apollonails',
#      u'Apollonails-guest',
#      u'AppleNet',
#      u'Auggie',
#      u'B-TAPMYBOX_2.4',
#      u'BAJR',
#      u'BKJ-Home',
#      u'Backfire',
#      u'BeOurGuest',
#      u'Bill Wi The Science Fi',
#      u'Blumpkinet',
#      u'Bomquisha',
#      u'BonerJams02',
#      u"Brittin's Guest Network",
#      u"Brittin's Wi-Fi Network",
#      u'BuckyBadger',
#      u'Byrdhouse',
#      u'CBCI-806D-2.4',
#      u'CBCI-EC1E-2.4',
#      u'CalebRules',
#      u'Canterbury',
#      u"Cara's Wi-Fi Network",
#      u'CarlosM',
#      u'CasaBarlita',
#      u'CasaDeCurry',
#      u'Cascadelink Free Wifi',
#      u'Cascadelink407_2.4G',
#      u'CenturyLink0199',
#      u'CenturyLink0297',
#      u'CenturyLink074a',
#      u'CenturyLink0921',
#      u'CenturyLink1543',
#      u'CenturyLink1913',
#      u'CenturyLink1951',
#      u'CenturyLink1980',
#      u'CenturyLink2262',
#      u'CenturyLink2417',
#      u'CenturyLink2457',
#      u'CenturyLink2467',
#      u'CenturyLink2828',
#      u'CenturyLink2894',
#      u'CenturyLink3157',
#      u'CenturyLink3374',
#      u'CenturyLink3575',
#      u'CenturyLink4005',
#      u'CenturyLink4104',
#      u'CenturyLink4435',
#      u'CenturyLink4795',
#      u'CenturyLink5264',
#      u'CenturyLink7246',
#      u'CenturyLink8523',
#      u'CenturyLink9273',
#      u'Chenrezig',
#      u'Chris-WiFi',
#      u'CityBoos-guest',
#      u'ClubNiaNPhia',
#      u'CoffeeBlackWhiskeyNeat-2.4',
#      u'Crazy Plant Lady',
#      u'CuaHan',
#      u'DCHQ-1',
#      u'DIEYUPPIESCUM!!!',
#      u'DIRECT-01-HP ENVY 4520 series',
#      u'DIRECT-3E-HP ENVY 4520 series',
#      u'DIRECT-40-HP Officejet 5740',
#      u'DIRECT-72-HP ENVY 4520 series',
#      u'DIRECT-86-HP OfficeJet Pro 6970',
#      u'DIRECT-9A-HP ENVY 5540 series',
#      u'DIRECT-A6-HP ENVY 4520 series',
#      u'DIRECT-DE-HP ENVY 7640 series',
#      u'DIRECT-Df[TV]UN46EH5300',
#      u'DIRECT-NI-VIZIOTV',
#      u'DIRECT-UA-VIZIOTV',
#      u'DIRECT-f5-HP M452 LaserJet',
#      u'DIRECT-sdC48x Series',
#      u'DIRECT-yP-BRAVIA',
#      u'Dactylnet',
#      u'Dahngrest',
#      u'DinsFirewall',
#      u'DumpsterKitten-2.4',
#      u'Dvorak',
#      u'ERMAHGERD! WIERFIER',
#      u'Ephspride',
#      u'Evawifi',
#      u'FBI_Surveillance_Van',
#      u'Fireman Pole Neighbors',
#      u'FlowersOn15th',
#      u'Focke',
#      u'Freedom',
#      u'GLnTZ',
#      u'GLnTZ_2.4_Guest1',
#      u'Gabarama',
#      u'Get Off My LAN',
#      u'Gillooly',
#      u'Gooddeed',
#      u'Google Starbucks',
#      u'GrandArchives',
#      u'GreenBike',
#      u'Guestquarters',
#      u'HOME FE73 5',
#      u'HOME-20FB-2.4',
#      u'HOME-232E',
#      u'HOME-2812',
#      u'HOME-2984-2.4',
#      u'HOME-2C78-2.4',
#      u'HOME-3335-2.4',
#      u'HOME-3557-2.4',
#      u'HOME-3767-2.4',
#      u'HOME-3F63-2.4',
#      u'HOME-481C-2.4',
#      u'HOME-4B98',
#      u'HOME-5082-2.4',
#      u'HOME-5712',
#      u'HOME-5D20-2.4',
#      u'HOME-5F46-2.4',
#      u'HOME-6444-2.4',
#      u'HOME-6B72',
#      u'HOME-71F5-2.4',
#      u'HOME-7850',
#      u'HOME-7AB5',
#      u'HOME-83A5-2.4',
#      u'HOME-8B02',
#      u'HOME-8B64',
#      u'HOME-8DF2-2.4',
#      u'HOME-8E3D-2.4',
#      u'HOME-973E-2.4',
#      u'HOME-9937',
#      u'HOME-9D32',
#      u'HOME-9F32',
#      u'HOME-A1B4-2.4',
#      u'HOME-A60E-2.4',
#      u'HOME-A994-2.4',
#      u'HOME-AA73-2.4',
#      u'HOME-AEC1-2.4',
#      u'HOME-B7D4-2.4',
#      u'HOME-BBD2',
#      u'HOME-C6C3',
#      u'HOME-D0A2',
#      u'HOME-D0D2',
#      u'HOME-D152',
#      u'HOME-D3EC',
#      u'HOME-DC90-2.4',
#      u'HOME-E1D8-2.4',
#      u'HOME-E433-2.4',
#      u'HOME-ED43-2.4',
#      u'HOME-EFD0-2.4',
#      u'HOME-F4BE-2.4',
#      u'HOME-F999',
#      u'HOME-FD92',
#      u'HOMEwifi',
#      u'HP-Print-54-Photosmart 7520',
#      u'HP-Print-66-Officejet Pro 8600',
#      u'HP-Print-88-Photosmart 5520',
#      u'HP-Print-8A-Officejet Pro 8600',
#      u'HP-Print-F7-Officejet Pro 8610',
#      u'Haus Homo',
#      u'Hermes',
#      u'HilltopService',
#      u'Home',
#      u'Home-0BF0',
#      u'HomeShim',
#      u'Huckleberry',
#      u'HuginnAndMuninn-2.4G',
#      u'I<3TIM_2.4',
#      u'In Da Clerb We All Fam',
#      u'In a row',
#      u'Internetz',
#      u'IslandGirl-2.4',
#      u'J-J',
#      u'JCN',
#      u'Jergen',
#      u"Judy's Chromecast",
#      u'JuliaRose',
#      u'JuulFam',
#      u'KER01',
#      u'KER03',
#      u'KimJongIllmatic',
#      u'KingdomOfLoathing2.4',
#      u'Kittynet',
#      u'KoL_Guest',
#      u'LAN Before Time',
#      u'LAN of the Lost',
#      u'LadyBug',
#      u'LexxinWland',
#      u'LoHo',
#      u'LordofthePings',
#      u'MADMEN',
#      u'MESA',
#      u'MOTOROLA-5A2AD',
#      u'MR_MEESEEKS',
#      u'MY SIN',
#      u'MaldenHOME24GHz',
#      u'MaldenHOME24GHz_EXT',
#      u'Manco Capac',
#      u'Manurism',
#      u'Marquand-24',
#      u'Martini-2.4',
#      u"Mary's Wi-Fi Network",
#      u'Mister Butterworth',
#      u'MisterKitty',
#      u'MoonShadow',
#      u'MusicNet 2',
#      u'NETGEAR',
#      u'NETGEAR-2.4-G',
#      u'NETGEAR07',
#      u'NETGEAR1',
#      u'NETGEAR11',
#      u'NETGEAR12',
#      u'NETGEAR26',
#      u'NETGEAR28',
#      u'NETGEAR29',
#      u'NETGEAR33',
#      u'NETGEAR55',
#      u'NETGEAR57',
#      u'NETGEAR69',
#      u'NETGEAR75',
#      u'NETGEAR94',
#      u'NTGR_VMB_1490668556',
#      u'Nedlam',
#      u'NorwaySweden85',
#      u'Orange',
#      u'PB&J',
#      u'PS4-59CFAFA658DC',
#      u'Panda Extreme',
#      u'Pap2. 4',
#      u'Pastasauce',
#      u'Pipe Laying Inc.',
#      u'PizzaParty',
#      u'PrimeN',
#      u'Putty_3',
#      u'RCT',
#      u'RJK',
#      u'RLM',
#      u'RadicalMajik69',
#      u'Ristretto 2.4',
#      u'Roadhouse',
#      u"Ron Dayne's House",
#      u'Running at an incredible rate',
#      u'Russell',
#      u"Ryno's Ri-Fi Network",
#      u'SEC_LinkShare_e6df14',
#      u'SEC_LinkShare_ebaba3',
#      u'SETUP',
#      u'SHERLOCKED',
#      u'Screaming Temporal Doom',
#      u'Screaming Temporal Doom-guest',
#      u'SeAnCaLink',
#      u'Seattle Law',
#      u'Seattle-2.4',
#      u'Seawolf1',
#      u'Seda',
#      u'ShinyDove',
#      u'ShinyDove-guest',
#      u'Snow-Report',
#      u'Spinnersend',
#      u'Starbird',
#      u'SuWon2',
#      u'TP-LINK_0621',
#      u'TP-LINK_2.4GHz_090491',
#      u'TP-LINK_2.4GHz_B29219',
#      u'TP-LINK_4B59',
#      u'TP-LINK_5595',
#      u'TP-LINK_A7B5',
#      u'TP-LINK_EC64',
#      u'TWAIN',
#      u'Tazmania',
#      u'Thames-N',
#      u'The Castle',
#      u'The Interwebz',
#      u'The Manor',
#      u'The Nest',
#      u'The Tavern',
#      u'The2.4',
#      u'Tony',
#      u'Tootsieroll',
#      u'Trophy Husband',
#      u'UnicornPorn',
#      u'Verizon-MiFi6620L-5253',
#      u'WEEPINGANGEL',
#      u'WIRELESSNET2',
#      u'WLAN-TWDC',
#      u'WaveG Public WiFi',
#      u'Willtrade4weed',
#      u'Winternet is coming!',
#      u'XFINITY',
#      u'Zeiss',
#      u'Zoom7099',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00',
#      u'bearbrowsing',
#      u'beckywiththegoodhair',
#      u'belkin.5af',
#      u'belkin.5af.guests',
#      u'belkin.6ee',
#      u'belkin.6ee.guests',
#      u'belkin.de2.guests',
#      u'bengals',
#      u'chelseagrin',
#      u'dlink',
#      u'dropbear',
#      u'f33db4ck',
#      u'fbisurveillance-2.4',
#      u'ferry',
#      u'filkorchi',
#      u'galilieo',
#      u'gargantua-1',
#      u'glitternet',
#      u'hearts in sf',
#      u'hoembaes',
#      u'hondarageing2G',
#      u'hoopburg',
#      u'ineedanonion24',
#      u'kiiiirk',
#      u'lifeaquatic',
#      u'linksys',
#      u'linksys_98112_4515',
#      u'm0ckingb3rd',
#      u'mkwireless',
#      u'montynet-2.4',
#      u'mothbones',
#      u'myqwest2797',
#      u'myqwest6091',
#      u'myqwest7452',
#      u'myqwest8073',
#      u'myqwest98112',
#      u'nextstep24',
#      u'night',
#      u'password is password',
#      u'pericolos',
#      u'phenomenology',
#      u'rkcdbp',
#      u'rugsi',
#      u'safewaywifi',
#      u'salmo',
#      u'scudder',
#      u'seese',
#      u'shenanigans',
#      u'spacecadet',
#      u'sverige',
#      u'swaaa',
#      u'swsecure',
#      u'unicornfury',
#      u'xfinitywifi',
#      u'yoalex'])

# %% [markdown]
# # Extracting Experiment Dates/Times
#
# We can extract timestamps from all of our wifi experiments and figure out how many experiments we have and what their date and time ranges are. To do this, we will create two sets of timestamps: one for thing1 and one for thing2. We can use either the `ap_data` or the `client_data` table. The `client_data` table is about 5 times smaller, so let's go with that one.

# %%
hosts = ['thing1','thing2']
timestamp_sets = []

for host in hosts:
    cursor = client_collection.find({'host': host})
    
    times = set()
    for j,doc in enumerate(cursor):
        times.add(doc['time'])
    
    timestamp_sets.append(times)
    print("Host %s: found %d timestamps"%(host,len(times)))
# Out:
# Host thing1: found 3682 timestamps
# Host thing2: found 421 timestamps

# %% [markdown]
# Now we will plot the timestamps on the x axis, and plot a 1 on the y axis if it is an experiment with thing1 and a 2 on the y axis if it is an experiment with thing2.

# %%
fig = plt.figure(figsize=(14,4))
ax = fig.add_subplot(111)

for i,host in enumerate(hosts):

    xx = list(timestamp_sets[i])
    yy = [i+1,]*len(xx)

    ax.plot(xx,yy,'o')
    
ax.set_ylim([0,5])
fig.autofmt_xdate()

# %% [markdown]
# Thing1 experiments:
# * First experiment was on or around April 14th, so if we want to extract only data from the first experiment with thing1, we can search for all data between April 13 and April 15 where the "host" field matches "thing1".
# * Second experiment was on or around April 24th, so if we want to extract data from the second experiment we can look for data between April 23 and April 25 where the host is thing1.
#
# Thing2 experiments:
# * First experiment was on or around April 14th
# * Second experiment was on or around April 24th.
